# %%
import pandas as pd

# %%
# !pip install xlrd
# Out:
# ...
#   Obtaining dependency information for xlrd from https://files.pythonhosted.org/packages/1a/62/c8d562e7766786ba6587d09c5a8ba9f718ed3fa8af7f4553e8f91c36f302/xlrd-2.0.2-py2.py3-none-any.whl.metadata
# ...
# Using cached xlrd-2.0.2-py2.py3-none-any.whl (96 kB)
# ...

# %%
pip install openpyxl
# Out:
# ...
#
# ...

# %%
pip install pyxlsb
# Out:
# ...
#   Obtaining dependency information for pyxlsb from https://files.pythonhosted.org/packages/7e/92/345823838ae367c59b63e03aef9c331f485370f9df6d049256a61a28f06d/pyxlsb-1.0.10-py2.py3-none-any.whl.metadata
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install lxml py arrow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
with open(r"C:\Users\angel\OneDrive\Documents\Multiverse DS ADF 2\Module 3\Module 3 - Portfolio Project\Oracle data\no-capital-oracle-2022-2023-export-01-08-2025.xls", "rb") as f: print(f.read(10))


#ncap_2023_2024 = pd.read_excel(r"C:\Users\angel\OneDrive\Documents\Multiverse DS ADF 2\Module 3\Module 3 - Portfolio Project\Oracle data\no-capital-oracle-2022-2023-export-01-08-2025.xls", engine="pyxlsb")
# Out:
# b'<html>\r\n<!'

# %%
ncap_2023_2024 = pd.read_html(r"C:\Users\angel\OneDrive\Documents\Multiverse DS ADF 2\Module 3\Module 3 - Portfolio Project\Oracle data\no-capital-oracle-2022-2023-export-01-08-2025.xls")

# %%
import pandas as pd
df = pd.read_parquet(r"C:\Users\angel\OneDrive\Documents\Multiverse DS ADF 2\Module 3\Module 3 - Portfolio Project\Oracle data\no-capital-oracle-2022-2023-export-01-08-2025.parquet")

# %%
df
# Out:
#         col1  col2  col3  col4  col5  col6  col7  col8  col9  col10  ...  \
# 0        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN  ...
# 1        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN  ...
# 2        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN  ...
# 3        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN  ...
# 4        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN  ...
# ...      ...   ...   ...   ...   ...   ...   ...   ...   ...    ...  ...
# 572268   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN  ...
# 572269   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN  ...
# 572270   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN  ...
# 572271   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN  ...
# 572272   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN  ...
#
#         col24  col25  col26  col27  col28  col29  col30  col31  col32  col33
# ...
